# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\David\Desktop\Project for work\Eluvio_DS_Challenge.csv')
data
# Out:
#         time_created date_created  up_votes  down_votes  \
# 0         1201232046   2008-01-25         3           0
# 1         1201232075   2008-01-25         2           0
# 2         1201232523   2008-01-25         3           0
# 3         1201233290   2008-01-25         1           0
# 4         1201274720   2008-01-25         4           0
# ...              ...          ...       ...         ...
# 509231    1479816764   2016-11-22         5           0
# 509232    1479816772   2016-11-22         1           0
# 509233    1479817056   2016-11-22         1           0
# 509234    1479817157   2016-11-22         1           0
# 509235    1479817346   2016-11-22         1           0
#
#                                                     title  over_18  \
# 0                       Scores killed in Pakistan clashes    False
# 1                        Japan resumes refuelling mission    False
# 2                         US presses Egypt on Gaza border    False
# ...

# %%
data.head(20)
# Out:
#     time_created date_created  up_votes  down_votes  \
# 0     1201232046   2008-01-25         3           0
# 1     1201232075   2008-01-25         2           0
# 2     1201232523   2008-01-25         3           0
# 3     1201233290   2008-01-25         1           0
# 4     1201274720   2008-01-25         4           0
# 5     1201287889   2008-01-25        15           0
# 6     1201289438   2008-01-25         5           0
# 7     1201536662   2008-01-28         0           0
# 8     1201558396   2008-01-28         4           0
# 9     1201635869   2008-01-29         3           0
# 10    1201701773   2008-01-30         4           0
# 11    1201719875   2008-01-30         9           0
# 12    1201722210   2008-01-30         1           0
# 13    1201765485   2008-01-31         1           0
# 14    1201794451   2008-01-31         2           0
# 15    1201794900   2008-01-31         3           0
# 16    1201799407   2008-01-31         7           0
# ...

# %%
cleaned_data = data.drop(["category","time_created","date_created"], axis = 1, inplace = False)
cleaned_data # I clean above mentioned columns because they don't need for projection
# Out:
#         up_votes  down_votes  \
# 0              3           0
# 1              2           0
# 2              3           0
# 3              1           0
# 4              4           0
# ...          ...         ...
# 509231         5           0
# 509232         1           0
# 509233         1           0
# 509234         1           0
# 509235         1           0
#
#                                                     title  over_18  \
# 0                       Scores killed in Pakistan clashes    False
# 1                        Japan resumes refuelling mission    False
# 2                         US presses Egypt on Gaza border    False
# 3            Jump-start economy: Give health care to all     False
# 4         Council of Europe bashes EU&UN terror blacklist    False
# ...                                                   ...      ...
# 509231   Heil Trump : Donald Trump s  alt-right  white...    False
# ...

# %%
cleaned_data.shape
# Out:
# (509236, 5)

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
print (list(cleaned_data.columns))
# Out:
# ['up_votes', 'down_votes', 'title', 'over_18', 'author']

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
df_new_train = cleaned_data.replace({False:0,True:1})

# %%
X = df_new_train.drop(["title","author", "over_18"], axis = 1, inplace = False)
y = pd.DataFrame(df_new_train["over_18"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 1)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
print ('Test RMSE over_18:', np.sqrt(mean_squared_error(predictions, y_test)))
print ('Train RMSE over_18:', np.sqrt(mean_squared_error(lm.predict(X_train), y_train)))
# Out:
# Test RMSE over_18: 0.02276333971125454
# Train RMSE over_18: 0.025777540490324893
